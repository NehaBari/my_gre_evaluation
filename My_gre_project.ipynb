# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import io
import requests
# %matplotlib inline

df1=pd.read_csv('GRE_ANA.csv')
df1.head()
# Out:
#    GRE_Quant  GRE_Verbal  GRE_AWA  GPA  Admit  Rank
# 0        170         153      2.5  2.0      0    25
# 1        165         150      3.0  3.0      1    30
# 2        155         144      3.5  3.5      0    15
# 3        153         140      4.0  4.0      1    20
# 4        157         165      4.5  4.0      3    79

# %%
print(type(df1))
print(dataset.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (214, 1)

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
# GRE_Quant     9 non-null int64
# GRE_Verbal    9 non-null int64
# GRE_AWA       9 non-null float64
# GPA           9 non-null float64
# Admit         9 non-null int64
# Rank          9 non-null int64
# dtypes: float64(2), int64(4)
# memory usage: 512.0 bytes
# None

# %%
print(df1.count())
# Out:
# GRE_Quant     9
# GRE_Verbal    9
# GRE_AWA       9
# GPA           9
# Admit         9
# Rank          9
# dtype: int64

# %%
print(df1.columns)
# Out:
# Index(['GRE_Quant', 'GRE_Verbal', 'GRE_AWA', 'GPA', 'Admit', 'Rank'], dtype='object')

# %%
print(df1.sum())
# Out:
# GRE_Quant     1371.0
# GRE_Verbal    1395.0
# GRE_AWA         37.0
# GPA             27.3
# Admit           10.0
# Rank           327.0
# dtype: float64

# %%
print(df1.describe())
# Out:
#         GRE_Quant  GRE_Verbal   GRE_AWA       GPA     Admit       Rank
# count    9.000000    9.000000  9.000000  9.000000  9.000000   9.000000
# mean   152.333333  155.000000  4.111111  3.033333  1.111111  36.333333
# std     10.630146   10.087121  1.219062  0.871780  1.166667  21.459264
# min    140.000000  140.000000  2.500000  1.500000  0.000000  15.000000
# 25%    144.000000  150.000000  3.000000  2.500000  0.000000  20.000000
# 50%    153.000000  153.000000  4.000000  3.300000  1.000000  30.000000
# 75%    157.000000  163.000000  5.000000  3.500000  1.000000  45.000000
# max    170.000000  170.000000  6.000000  4.000000  3.000000  79.000000

# %%
print(df1.mean())
# Out:
# GRE_Quant     152.333333
# GRE_Verbal    155.000000
# GRE_AWA         4.111111
# GPA             3.033333
# Admit           1.111111
# Rank           36.333333
# dtype: float64

# %%
print(df1.median())
# Out:
# GRE_Quant     153.0
# GRE_Verbal    153.0
# GRE_AWA         4.0
# GPA             3.3
# Admit           1.0
# Rank           30.0
# dtype: float64

# %%
#lets get started with data visualization
#yipeee!!
import seaborn as sns
sns.set(style="white",context="talk")
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,6))
sns.distplot(df1.iloc[:,1], ax=ax1, color="r");
sns.distplot(df1.iloc[:,2], ax=ax2, color="g");


#the analysis would have been difficult to guess with excel fie
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-68-0fe40a5bf313> in <module>()
#       7 sns.distplot(df1.iloc[:,2], ax=ax2, color="g");
#       8
# ----> 9 head(df1)
#      10
#      11
#
# NameError: name 'head' is not defined

# %%
#multivariance analysis

sns.pairplot(df1, hue='Admit', palette="husl", x_vars=["GRE_Quant", "GPA", "Rank"],
            y_vars=["GRE_Quant", "GPA", "Rank"], size=4)

sns.plt.show()
# Out:
# ----------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-71-3ba4973a45c3> in <module>()
#       4             y_vars=["GRE_Quant", "GPA", "Rank"], size=4)
#       5
# ----> 6 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'
